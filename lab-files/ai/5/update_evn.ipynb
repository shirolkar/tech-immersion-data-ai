# %%
# !pip show onnx
# Out:
# Name: onnx
# Version: 1.4.1
# Summary: Open Neural Network Exchange
# Home-page: https://github.com/onnx/onnx
# Author: bddppq
# Author-email: jbai@fb.com
# License: UNKNOWN
# Location: /data/anaconda/envs/py35/lib/python3.5/site-packages
# Requires: numpy, protobuf, typing-extensions, typing, six
# Required-by: skl2onnx, onnxmltools, onnxconverter-common, onnx-mxnet, onnx-chainer, keras2onnx, azureml-train-automl, azureml-automl-core, tf2onnx

# %%
# !pip install onnx==1.5.0
# !pip install onnx-chainer==1.4.1
# !pip install onnx-mxnet==0.4.2
# !pip install onnxconverter-common==1.5.0
# !pip install onnxmltools==1.5.0
# !pip install onnxruntime==0.4.0
# Out:
# Requirement already satisfied: onnx==1.5.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (1.5.0)
# Requirement already satisfied: numpy in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx==1.5.0) (1.14.6)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx==1.5.0) (3.7.2)
# Requirement already satisfied: protobuf in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx==1.5.0) (3.6.1)
# Requirement already satisfied: six in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx==1.5.0) (1.11.0)
# Requirement already satisfied: typing>=3.6.4 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx==1.5.0) (3.6.4)
# Requirement already satisfied: setuptools in /data/anaconda/envs/py35/lib/python3.5/site-packages (from protobuf->onnx==1.5.0) (40.2.0)
# mxnet-model-server 1.0.1 requires model-archiver, which is not installed.
# flake8 3.7.5 has requirement pycodestyle<2.6.0,>=2.5.0, but you'll have pycodestyle 2.4.0 which is incompatible.
# skl2onnx 1.4.9 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# mxnet 1.3.0 has requirement requests<2.19.0,>=2.18.4, but you'll have requests 2.22.0 which is incompatible.
# blobxfer 1.6.0 has requirement requests~=2.21.0, but you'll have requests 2.22.0 which is incompatible.
# blobxfer 1.6.0 has requirement ruamel.yaml~=0.15.85, but you'll have ruamel-yaml 0.15.35 which is incompatible.
# chainermn 1.3.1 has requirement chainer<5.0,>=3.5.0, but you'll have chainer 5.2.0 which is incompatible.
# autovizwidget 0.12.7 has requirement plotly<3.0,>=1.10.0, but you'll have plotly 3.6.1 which is incompatible.
# azureml-contrib-opendatasets 1.0.33 has requirement azureml-telemetry==1.0.33.*, but you'll have azureml-telemetry 1.0.48 which is incompatible.
# botocore 1.12.93 has requirement urllib3<1.25,>=1.20; python_version >= "3.4", but you'll have urllib3 1.25.3 which is incompatible.
# Collecting onnx-chainer==1.4.1
#   Downloading https://files.pythonhosted.org/packages/e0/20/5077c57feab5166343eb01ab77fcf0bddfa42eb40b7262a0d84281e999f1/onnx-chainer-1.4.1.tar.gz
# Requirement already satisfied: chainer>=5.0.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx-chainer==1.4.1) (5.2.0)
# Collecting onnx<1.5,>=1.4.0 (from onnx-chainer==1.4.1)
#   Downloading https://files.pythonhosted.org/packages/be/00/90b3b0330e608ef1a29eff972adc77bff524b5500b47fce1d579a96d4be6/onnx-1.4.1-cp35-cp35m-manylinux1_x86_64.whl (6.9MB)
#     100% |████████████████████████████████| 6.9MB 7.9MB/s eta 0:00:01
# Requirement already satisfied: filelock in /data/anaconda/envs/py35/lib/python3.5/site-packages (from chainer>=5.0.0->onnx-chainer==1.4.1) (3.0.4)
# Requirement already satisfied: numpy>=1.9.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from chainer>=5.0.0->onnx-chainer==1.4.1) (1.14.6)
# Requirement already satisfied: protobuf>=3.0.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from chainer>=5.0.0->onnx-chainer==1.4.1) (3.6.1)
# Requirement already satisfied: six>=1.9.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from chainer>=5.0.0->onnx-chainer==1.4.1) (1.11.0)
# Requirement already satisfied: cupy<6.0.0,>=5.2.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from chainer>=5.0.0->onnx-chainer==1.4.1) (5.2.0)
# Requirement already satisfied: typing>=3.6.4 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx<1.5,>=1.4.0->onnx-chainer==1.4.1) (3.6.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx<1.5,>=1.4.0->onnx-chainer==1.4.1) (3.7.2)
# Requirement already satisfied: setuptools in /data/anaconda/envs/py35/lib/python3.5/site-packages (from protobuf>=3.0.0->chainer>=5.0.0->onnx-chainer==1.4.1) (40.2.0)
# Requirement already satisfied: fastrlock>=0.3 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from cupy<6.0.0,>=5.2.0->chainer>=5.0.0->onnx-chainer==1.4.1) (0.4)
# Building wheels for collected packages: onnx-chainer
#   Running setup.py bdist_wheel for onnx-chainer ... done
#   Stored in directory: /home/azureuser/.cache/pip/wheels/f4/a8/a5/801f5b4afde385e5cb1d023026556ea8bbc786c1aed9b9ef26
# Successfully built onnx-chainer
# mxnet-model-server 1.0.1 requires model-archiver, which is not installed.
# flake8 3.7.5 has requirement pycodestyle<2.6.0,>=2.5.0, but you'll have pycodestyle 2.4.0 which is incompatible.
# botocore 1.12.93 has requirement urllib3<1.25,>=1.20; python_version >= "3.4", but you'll have urllib3 1.25.3 which is incompatible.
# autovizwidget 0.12.7 has requirement plotly<3.0,>=1.10.0, but you'll have plotly 3.6.1 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# chainermn 1.3.1 has requirement chainer<5.0,>=3.5.0, but you'll have chainer 5.2.0 which is incompatible.
# mxnet 1.3.0 has requirement requests<2.19.0,>=2.18.4, but you'll have requests 2.22.0 which is incompatible.
# azureml-contrib-opendatasets 1.0.33 has requirement azureml-telemetry==1.0.33.*, but you'll have azureml-telemetry 1.0.48 which is incompatible.
# skl2onnx 1.4.9 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# blobxfer 1.6.0 has requirement requests~=2.21.0, but you'll have requests 2.22.0 which is incompatible.
# blobxfer 1.6.0 has requirement ruamel.yaml~=0.15.85, but you'll have ruamel-yaml 0.15.35 which is incompatible.
# Installing collected packages: onnx, onnx-chainer
#   Found existing installation: onnx 1.5.0
#     Uninstalling onnx-1.5.0:
#       Successfully uninstalled onnx-1.5.0
#   Found existing installation: onnx-chainer 1.3.2
#     Uninstalling onnx-chainer-1.3.2:
#       Successfully uninstalled onnx-chainer-1.3.2
# Successfully installed onnx-1.4.1 onnx-chainer-1.4.1
# Requirement already satisfied: onnx-mxnet==0.4.2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (0.4.2)
# Requirement already satisfied: onnx>=1.0.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx-mxnet==0.4.2) (1.4.1)
# Requirement already satisfied: mxnet>=0.11.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages/mxnet-1.3.0-py3.5.egg (from onnx-mxnet==0.4.2) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx>=1.0.1->onnx-mxnet==0.4.2) (3.7.2)
# Requirement already satisfied: six in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx>=1.0.1->onnx-mxnet==0.4.2) (1.11.0)
# Requirement already satisfied: numpy in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx>=1.0.1->onnx-mxnet==0.4.2) (1.14.6)
# Requirement already satisfied: typing>=3.6.4 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx>=1.0.1->onnx-mxnet==0.4.2) (3.6.4)
# Requirement already satisfied: protobuf in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx>=1.0.1->onnx-mxnet==0.4.2) (3.6.1)
# Collecting requests<2.19.0,>=2.18.4 (from mxnet>=0.11.0->onnx-mxnet==0.4.2)
#   Downloading https://files.pythonhosted.org/packages/49/df/50aa1999ab9bde74656c2919d9c0c085fd2b3775fd3eca826012bef76d8c/requests-2.18.4-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 24.4MB/s ta 0:00:01
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from mxnet>=0.11.0->onnx-mxnet==0.4.2) (0.8.4)
# Requirement already satisfied: setuptools in /data/anaconda/envs/py35/lib/python3.5/site-packages (from protobuf->onnx>=1.0.1->onnx-mxnet==0.4.2) (40.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests<2.19.0,>=2.18.4->mxnet>=0.11.0->onnx-mxnet==0.4.2) (2018.8.24)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests<2.19.0,>=2.18.4->mxnet>=0.11.0->onnx-mxnet==0.4.2) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests<2.19.0,>=2.18.4->mxnet>=0.11.0->onnx-mxnet==0.4.2) (2.6)
# Collecting urllib3<1.23,>=1.21.1 (from requests<2.19.0,>=2.18.4->mxnet>=0.11.0->onnx-mxnet==0.4.2)
#   Downloading https://files.pythonhosted.org/packages/63/cb/6965947c13a94236f6d4b8223e21beb4d576dc72e8130bd7880f600839b8/urllib3-1.22-py2.py3-none-any.whl (132kB)
#     100% |████████████████████████████████| 133kB 29.6MB/s ta 0:00:01
# mxnet-model-server 1.0.1 requires model-archiver, which is not installed.
# autovizwidget 0.12.7 has requirement plotly<3.0,>=1.10.0, but you'll have plotly 3.6.1 which is incompatible.
# azureml-train-restclients-hyperdrive 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# chainermn 1.3.1 has requirement chainer<5.0,>=3.5.0, but you'll have chainer 5.2.0 which is incompatible.
# blobxfer 1.6.0 has requirement requests~=2.21.0, but you'll have requests 2.18.4 which is incompatible.
# blobxfer 1.6.0 has requirement ruamel.yaml~=0.15.85, but you'll have ruamel-yaml 0.15.35 which is incompatible.
# azureml-core 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# azureml-core 1.0.48 has requirement urllib3>=1.23, but you'll have urllib3 1.22 which is incompatible.
# flake8 3.7.5 has requirement pycodestyle<2.6.0,>=2.5.0, but you'll have pycodestyle 2.4.0 which is incompatible.
# skl2onnx 1.4.9 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azure-datalake-store 0.0.41 has requirement requests>=2.20.0, but you'll have requests 2.18.4 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-contrib-opendatasets 1.0.33 has requirement azureml-telemetry==1.0.33.*, but you'll have azureml-telemetry 1.0.48 which is incompatible.
# Installing collected packages: urllib3, requests
#   Found existing installation: urllib3 1.25.3
#     Uninstalling urllib3-1.25.3:
#       Successfully uninstalled urllib3-1.25.3
#   Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
# Successfully installed requests-2.18.4 urllib3-1.22
# Requirement already satisfied: onnxconverter-common==1.5.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (1.5.0)
# Requirement already satisfied: numpy in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxconverter-common==1.5.0) (1.14.6)
# Requirement already satisfied: protobuf in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxconverter-common==1.5.0) (3.6.1)
# Requirement already satisfied: onnx in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxconverter-common==1.5.0) (1.4.1)
# Requirement already satisfied: six in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxconverter-common==1.5.0) (1.11.0)
# Requirement already satisfied: setuptools in /data/anaconda/envs/py35/lib/python3.5/site-packages (from protobuf->onnxconverter-common==1.5.0) (40.2.0)
# Requirement already satisfied: typing>=3.6.4 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx->onnxconverter-common==1.5.0) (3.6.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx->onnxconverter-common==1.5.0) (3.7.2)
# mxnet-model-server 1.0.1 requires model-archiver, which is not installed.
# flake8 3.7.5 has requirement pycodestyle<2.6.0,>=2.5.0, but you'll have pycodestyle 2.4.0 which is incompatible.
# blobxfer 1.6.0 has requirement requests~=2.21.0, but you'll have requests 2.18.4 which is incompatible.
# blobxfer 1.6.0 has requirement ruamel.yaml~=0.15.85, but you'll have ruamel-yaml 0.15.35 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azure-datalake-store 0.0.41 has requirement requests>=2.20.0, but you'll have requests 2.18.4 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-contrib-opendatasets 1.0.33 has requirement azureml-telemetry==1.0.33.*, but you'll have azureml-telemetry 1.0.48 which is incompatible.
# skl2onnx 1.4.9 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# azureml-train-restclients-hyperdrive 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# chainermn 1.3.1 has requirement chainer<5.0,>=3.5.0, but you'll have chainer 5.2.0 which is incompatible.
# azureml-core 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# azureml-core 1.0.48 has requirement urllib3>=1.23, but you'll have urllib3 1.22 which is incompatible.
# autovizwidget 0.12.7 has requirement plotly<3.0,>=1.10.0, but you'll have plotly 3.6.1 which is incompatible.
# Collecting onnxmltools==1.5.0
#   Downloading https://files.pythonhosted.org/packages/9f/eb/831bd9a76a40fe9aaf9f885daaddc0e5a9e93cd76baa778ccfc059516dcd/onnxmltools-1.5.0-py2.py3-none-any.whl (285kB)
#     100% |████████████████████████████████| 286kB 29.9MB/s ta 0:00:01
# Requirement already satisfied: onnxconverter-common>=1.5.0 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (1.5.0)
# Requirement already satisfied: skl2onnx in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (1.4.9)
# Requirement already satisfied: six in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (1.11.0)
# Requirement already satisfied: numpy in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (1.14.6)
# Requirement already satisfied: onnx in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (1.4.1)
# Requirement already satisfied: protobuf in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (3.6.1)
# Requirement already satisfied: keras2onnx in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnxmltools==1.5.0) (1.5.0)
# Requirement already satisfied: scikit-learn>=0.19 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from skl2onnx->onnxmltools==1.5.0) (0.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx->onnxmltools==1.5.0) (3.7.2)
# Requirement already satisfied: typing>=3.6.4 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from onnx->onnxmltools==1.5.0) (3.6.4)
# Requirement already satisfied: setuptools in /data/anaconda/envs/py35/lib/python3.5/site-packages (from protobuf->onnxmltools==1.5.0) (40.2.0)
# Requirement already satisfied: keras in /data/anaconda/envs/py35/lib/python3.5/site-packages (from keras2onnx->onnxmltools==1.5.0) (2.2.4)
# Requirement already satisfied: requests in /data/anaconda/envs/py35/lib/python3.5/site-packages (from keras2onnx->onnxmltools==1.5.0) (2.18.4)
# Requirement already satisfied: scipy>=0.13.3 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools==1.5.0) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from keras->keras2onnx->onnxmltools==1.5.0) (1.0.9)
# Requirement already satisfied: pyyaml in /data/anaconda/envs/py35/lib/python3.5/site-packages (from keras->keras2onnx->onnxmltools==1.5.0) (3.12)
# Requirement already satisfied: keras-applications>=1.0.6 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from keras->keras2onnx->onnxmltools==1.5.0) (1.0.7)
# Requirement already satisfied: h5py in /data/anaconda/envs/py35/lib/python3.5/site-packages (from keras->keras2onnx->onnxmltools==1.5.0) (2.7.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->keras2onnx->onnxmltools==1.5.0) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->keras2onnx->onnxmltools==1.5.0) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->keras2onnx->onnxmltools==1.5.0) (2018.8.24)
# Requirement already satisfied: idna<2.7,>=2.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests->keras2onnx->onnxmltools==1.5.0) (2.6)
# mxnet-model-server 1.0.1 requires model-archiver, which is not installed.
# azureml-train-restclients-hyperdrive 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# autovizwidget 0.12.7 has requirement plotly<3.0,>=1.10.0, but you'll have plotly 3.6.1 which is incompatible.
# skl2onnx 1.4.9 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# azure-datalake-store 0.0.41 has requirement requests>=2.20.0, but you'll have requests 2.18.4 which is incompatible.
# flake8 3.7.5 has requirement pycodestyle<2.6.0,>=2.5.0, but you'll have pycodestyle 2.4.0 which is incompatible.
# azureml-core 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# azureml-core 1.0.48 has requirement urllib3>=1.23, but you'll have urllib3 1.22 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnxmltools==1.4.1, but you'll have onnxmltools 1.5.0 which is incompatible.
# azureml-contrib-opendatasets 1.0.33 has requirement azureml-telemetry==1.0.33.*, but you'll have azureml-telemetry 1.0.48 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnxmltools==1.4.1, but you'll have onnxmltools 1.5.0 which is incompatible.
# blobxfer 1.6.0 has requirement requests~=2.21.0, but you'll have requests 2.18.4 which is incompatible.
# blobxfer 1.6.0 has requirement ruamel.yaml~=0.15.85, but you'll have ruamel-yaml 0.15.35 which is incompatible.
# chainermn 1.3.1 has requirement chainer<5.0,>=3.5.0, but you'll have chainer 5.2.0 which is incompatible.
# Installing collected packages: onnxmltools
#   Found existing installation: onnxmltools 1.4.1
#     Uninstalling onnxmltools-1.4.1:
#       Successfully uninstalled onnxmltools-1.4.1
# Successfully installed onnxmltools-1.5.0
# Collecting onnxruntime==0.4.0
#   Downloading https://files.pythonhosted.org/packages/24/18/576d62d4c87b7d4f74872b4e48261017e0477211e7647080c31a9f8cd8cd/onnxruntime-0.4.0-cp35-cp35m-manylinux1_x86_64.whl (3.1MB)
#     100% |████████████████████████████████| 3.1MB 14.5MB/s ta 0:00:01
# mxnet-model-server 1.0.1 requires model-archiver, which is not installed.
# chainermn 1.3.1 has requirement chainer<5.0,>=3.5.0, but you'll have chainer 5.2.0 which is incompatible.
# azureml-contrib-opendatasets 1.0.33 has requirement azureml-telemetry==1.0.33.*, but you'll have azureml-telemetry 1.0.48 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-automl-core 1.0.48 has requirement onnxmltools==1.4.1, but you'll have onnxmltools 1.5.0 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnx>=1.5.0, but you'll have onnx 1.4.1 which is incompatible.
# azureml-train-automl 1.0.48 has requirement onnxmltools==1.4.1, but you'll have onnxmltools 1.5.0 which is incompatible.
# flake8 3.7.5 has requirement pycodestyle<2.6.0,>=2.5.0, but you'll have pycodestyle 2.4.0 which is incompatible.
# autovizwidget 0.12.7 has requirement plotly<3.0,>=1.10.0, but you'll have plotly 3.6.1 which is incompatible.
# skl2onnx 1.4.9 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# blobxfer 1.6.0 has requirement requests~=2.21.0, but you'll have requests 2.18.4 which is incompatible.
# blobxfer 1.6.0 has requirement ruamel.yaml~=0.15.85, but you'll have ruamel-yaml 0.15.35 which is incompatible.
# azureml-train-restclients-hyperdrive 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# azureml-core 1.0.48 has requirement requests>=2.19.1, but you'll have requests 2.18.4 which is incompatible.
# azureml-core 1.0.48 has requirement urllib3>=1.23, but you'll have urllib3 1.22 which is incompatible.
# azure-datalake-store 0.0.41 has requirement requests>=2.20.0, but you'll have requests 2.18.4 which is incompatible.
# Installing collected packages: onnxruntime
#   Found existing installation: onnxruntime 0.2.1
#     Uninstalling onnxruntime-0.2.1:
#       Successfully uninstalled onnxruntime-0.2.1
# Successfully installed onnxruntime-0.4.0
